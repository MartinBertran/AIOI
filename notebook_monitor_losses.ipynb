# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle
savepath = 'checkpoint/summary_losses_budget_5.00e-01.pkl'
with open(savepath,'rb') as f:
    save_dic = pickle.load(f)

# %%
loss_val = save_dic['loss_val']
loss_tr = save_dic['loss_tr']
loss_tr_u = save_dic['loss_tr_u']
loss_tr_s = save_dic['loss_tr_s']
loss_val_u = save_dic['loss_val_u']
loss_val_s = save_dic['loss_val_s']
infos = save_dic['infos']

# %%
plt.figure(figsize = (15,2))
plt.subplot(1,3,1)
plt.title('Loss')
plt.plot(loss_tr[:,0])
plt.plot(loss_val[:,0])

plt.subplot(1,3,2)
plt.title('Loss-utility component')
plt.plot(loss_tr[:,1])
plt.plot(loss_val[:,1])

plt.subplot(1,3,3)
plt.title('Loss-penalty component')
plt.plot((loss_tr[:,2]))
plt.plot((loss_val[:,2]))
plt.show()

# %%
plt.figure(figsize = (15,2))
plt.subplot(1,2,1)
plt.title(r'$I(U;X|Y)$')
plt.plot(infos[:,2])
plt.subplot(1,2,2)
plt.title(r'$I(S;Y)$')
plt.plot(infos[:,3])
plt.show()
